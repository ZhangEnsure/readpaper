# %%
import torch
from d2l import torch as d2l

import utils.config as config
from cnn.AlexNet import AlexNet
from utils.loadData import *
from utils.tools import *

import warnings 
warnings.filterwarnings("ignore")

# %%
print(config.num_classes)
# Out:
# 10

# %%
# torch.rand 返回一个 [0,1) 之间的均匀分布
x = torch.rand(size=(2,3,227,227))
net = AlexNet(num_classes = config.num_classes,dropout=config.dropout)
net(x).shape[0]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 4
#       2 x = torch.rand(size=(2,1,227,227))
#       3 net = AlexNet(num_classes = config.num_classes,dropout=config.dropout)
# ----> 4 net(x).shape[0]
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\readpaper\cnn\AlexNet.py:38, in AlexNet.forward(self, x)
#      37 def forward(self, x: torch.Tensor):
# ---> 38     x = self.features(x)
#      39     x = self.AdaptiveAvgPool2d(x)
#      40     x = self.flatten(x)
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torch\nn\modules\container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [64, 3, 11, 11], expected input[2, 1, 227, 227] to have 3 channels, but got 1 channels instead

# %% [markdown]
# 加载数据集
# 1. fashion_mnist
# 2. CIFAR10

# %%
# train_iter, test_iter = load_data_fashion_mnist(batch_size=config.batch_size,resize=config.resize)
train_iter, test_iter = load_data_cifar10(batch_size=config.batch_size,resize=config.resize)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../../data\cifar-10-python.tar.gz
# 0.1%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # train_iter, test_iter = load_data_fashion_mnist(batch_size=config.batch_size,resize=config.resize)
# ----> 2 train_iter, test_iter = load_data_cifar10(batch_size=config.batch_size,resize=config.resize)
#
# File e:\readpaper\utils\loadData.py:28, in load_data_cifar10(batch_size, resize)
#      26     trans.insert(0, transforms.Resize(resize))
#      27 trans = transforms.Compose(trans)
# ---> 28 cifar_train = torchvision.datasets.CIFAR10(
#      29     root="../../data", train=True, transform=trans, download=True)
#      30 cifar_test = torchvision.datasets.CIFAR10(
#      31     root="../../data", train=False, transform=trans, download=True)
#      32 return (data.DataLoader(cifar_train, batch_size, shuffle=True,
#      33                         num_workers=2),
#      34         data.DataLoader(cifar_test, batch_size, shuffle=False,
#      35                         num_workers=2))
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torchvision\datasets\cifar.py:65, in CIFAR10.__init__(self, root, train, transform, target_transform, download)
#      62 self.train = train  # training set or test set
#      64 if download:
# ---> 65     self.download()
#      67 if not self._check_integrity():
#      68     raise RuntimeError("Dataset not found or corrupted. You can use download=True to download it")
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torchvision\datasets\cifar.py:139, in CIFAR10.download(self)
#     137     print("Files already downloaded and verified")
#     138     return
# --> 139 download_and_extract_archive(self.url, self.root, filename=self.filename, md5=self.tgz_md5)
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torchvision\datasets\utils.py:447, in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     444 if not filename:
#     445     filename = os.path.basename(url)
# --> 447 download_url(url, download_root, filename, md5)
#     449 archive = os.path.join(download_root, filename)
#     450 print(f"Extracting {archive} to {extract_root}")
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torchvision\datasets\utils.py:157, in download_url(url, root, filename, md5, max_redirect_hops)
#     155 try:
#     156     print("Downloading " + url + " to " + fpath)
# --> 157     _urlretrieve(url, fpath)
#     158 except (urllib.error.URLError, OSError) as e:  # type: ignore[attr-defined]
#     159     if url[:5] == "https":
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torchvision\datasets\utils.py:48, in _urlretrieve(url, filename, chunk_size)
#      46 def _urlretrieve(url: str, filename: str, chunk_size: int = 1024 * 32) -> None:
#      47     with urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": USER_AGENT})) as response:
# ---> 48         _save_response_content(iter(lambda: response.read(chunk_size), b""), filename, length=response.length)
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torchvision\datasets\utils.py:37, in _save_response_content(content, destination, length)
#      31 def _save_response_content(
#      32     content: Iterator[bytes],
#      33     destination: str,
#      34     length: Optional[int] = None,
#      35 ) -> None:
#      36     with open(destination, "wb") as fh, tqdm(total=length) as pbar:
# ---> 37         for chunk in content:
#      38             # filter out keep-alive new chunks
#      39             if not chunk:
#      40                 continue
#
# File d:\download\anaconda3\envs\readpaper\lib\site-packages\torchvision\datasets\utils.py:48, in _urlretrieve.<locals>.<lambda>()
#      46 def _urlretrieve(url: str, filename: str, chunk_size: int = 1024 * 32) -> None:
#      47     with urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": USER_AGENT})) as response:
# ---> 48         _save_response_content(iter(lambda: response.read(chunk_size), b""), filename, length=response.length)
#
# File d:\download\anaconda3\envs\readpaper\lib\http\client.py:459, in HTTPResponse.read(self, amt)
#     456 if amt is not None:
#     457     # Amount is given, implement using readinto
#     458     b = bytearray(amt)
# --> 459     n = self.readinto(b)
#     460     return memoryview(b)[:n].tobytes()
#     461 else:
#     462     # Amount is not given (unbounded read) so we must check self.length
#     463     # and self.chunked
#
# File d:\download\anaconda3\envs\readpaper\lib\http\client.py:503, in HTTPResponse.readinto(self, b)
#     498         b = memoryview(b)[0:self.length]
#     500 # we do not use _safe_read() here because this may be a .will_close
#     501 # connection, and the user is reading more bytes than will be provided
#     502 # (for example, reading in 1k chunks)
# --> 503 n = self.fp.readinto(b)
#     504 if not n and b:
#     505     # Ideally, we would raise IncompleteRead if the content-length
#     506     # wasn't satisfied, but it might break compatibility.
#     507     self._close_conn()
#
# File d:\download\anaconda3\envs\readpaper\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File d:\download\anaconda3\envs\readpaper\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File d:\download\anaconda3\envs\readpaper\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# 开始训练

# %%
train_ch6(net, train_iter, test_iter, config.num_epochs, config.lr, d2l.try_gpu())
# Out:
# loss 0.189, train acc 0.928, test acc 0.919
# 611.9 examples/sec on cuda:0
